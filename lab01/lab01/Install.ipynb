# %% [markdown]
# # Modules to install

# %%
pip install datascience
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install otter-grader
# Out:
# ...
#   Obtaining dependency information for otter-grader from https://files.pythonhosted.org/packages/b2/e5/e4b1958dc95744539fd458a11c54b555a6bb9f275c1a6b9eef3ae6e8fab2/otter_grader-5.1.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for python-on-whales from https://files.pythonhosted.org/packages/b1/3b/84494b632d8964e51cb06db89988f2155e1ea62537ba0d70d974fc2a8967/python_on_whales-0.64.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for jupytext from https://files.pythonhosted.org/packages/d2/f5/d5f481cc9edb67c8d017a6eace529152ec496def175a87ce0aa158efc50e/jupytext-1.15.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for fica>=0.2.0 from https://files.pythonhosted.org/packages/32/b5/02a7a7b35b6aac188f87e88c5c9be3d6f957eb1a0e5331f9c4f5d8ba26a0/fica-0.3.1-py3-none-any.whl.metadata
# ...
